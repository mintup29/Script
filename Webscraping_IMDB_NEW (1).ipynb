# %% [markdown]
# ## Imports

# %%
pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)

# %%
from requests import get
from bs4 import BeautifulSoup
from warnings import warn
from time import sleep
from random import randint
import numpy as np, pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Scraping

# %% [markdown]
# ## Function Title Scraping per Genre

# %%
pages = np.arange(1, 100, 50)

# headers = {'Accept-Language': 'en-US,en;q=0.8'} # If this is not specified, the default language is Chinese
USER_AGENT = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0"
headers = {"user-agent" : USER_AGENT, 'Accept-Language': 'en-US,en;q=0.8'}

#initialize empty lists to store the variables scraped
titles = []

def title(genre):
  for page in pages:
    
    # https://www.imdb.com/search/title/?genres=action&start=51&explore=title_type,genres&ref_=adv_nxt
    # get request
    url = f"https://www.imdb.com/search/title?genres={genre}&start={page}&explore=title_type,genres&ref_=adv_nxt"
    response = get(url, headers=headers)
     
    # response = get("https://www.imdb.com/chart/top/?ref_=nv_mv_250", headers=headers)

    sleep(randint(8,15))
    
    #throw warning for status codes that are not 200
    if response.status_code != 200:
        warn('Request: {}; Status code: {}'.format(requests, response.status_code))

    #parse the content of current iteration of request
    page_html = BeautifulSoup(response.text, 'html.parser')
        
    movie_containers = page_html.find_all('div', class_ = 'lister-item mode-advanced')
    
    #extract the 50 movies for that page
    for container in movie_containers:
        #title
        title = container.h3.a.text
        titles.append(title)

# %%
genre = ['action', 'adventure', 'drama', 'comedy']
for genres in genre:
  title(genres)

# %%
title = pd.DataFrame({'movie': titles})
title
# Out:
#                                        movie
# 0             Guardians of the Galaxy Vol. 3
# 1                                    Citadel
# 2                          Peter Pan & Wendy
# 3    Dungeons & Dragons: Honor Among Thieves
# 4                             Dune: Part Two
# ..                                       ...
# 395                             Not Dead Yet
# 396                  The Wolf of Wall Street
# 397                                 Scream 4
# 398             Only Murders in the Building
# 399                                     Hook
#
# [400 rows x 1 columns]

# %%
title_df = pd.DataFrame({'movie': titles})
title_df
# Out:
#                                        movie
# 0             Guardians of the Galaxy Vol. 3
# 1                                    Citadel
# 2                          Peter Pan & Wendy
# 3    Dungeons & Dragons: Honor Among Thieves
# 4                             Dune: Part Two
# ..                                       ...
# 395                             Not Dead Yet
# 396                  The Wolf of Wall Street
# 397                                 Scream 4
# 398             Only Murders in the Building
# 399                                     Hook
#
# [400 rows x 1 columns]

# %%
title_df['movie'] = title_df['movie'].str.replace(r'[^\w\s]+', '')
title_df
# Out:
# <ipython-input-5-234103124b02>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   title_df['movie'] = title_df['movie'].str.replace(r'[^\w\s]+', '')
#                                      movie
# 0            Guardians of the Galaxy Vol 3
# 1                                  Citadel
# 2                         Peter Pan  Wendy
# 3    Dungeons  Dragons Honor Among Thieves
# 4                            Dune Part Two
# ..                                     ...
# 395                           Not Dead Yet
# 396                The Wolf of Wall Street
# 397                               Scream 4
# 398           Only Murders in the Building
# 399                                   Hook
#
# [400 rows x 1 columns]

# %% [markdown]
# ## Scraping Content

# %%
def find_imdb_url(query):
  query = query.replace(' ', '+')
  URL = f"https://google.com/search?q={query}+imdb"
  
  resp = get(URL, headers= headers)
  if resp.status_code == 200:
    soup = BeautifulSoup(resp.content, "html.parser") 
  
  hasil = []
  for g in soup.find_all('div', class_='g'):
    anchors = g.find_all('a')
    if anchors:
      link = anchors[0]['href']
    if "imdb.com" in link:
        hasil.append(link)
  return hasil[0]

# %%
query = 'Nope'
find_imdb_url(query)
# Out:
# 'https://www.imdb.com/title/tt10954984/'

# %%
def imdb_scrape(URL):
  # desktop user-agent
  resp = get(URL, headers= headers)

  if resp.status_code == 200:
      soup = BeautifulSoup(resp.content, "html.parser")


  for g in soup.find_all('section', class_ = 'ipc-page-background ipc-page-background--base sc-f9e7f53-0 ifXVtO'):
    movie_genre = []
    storyline = ''
    plot = ''

    try:
      for genres in g.find_all('div', class_ ="ipc-chip-list__scroller"):
        for genre in genres.find_all('span', class_ ="ipc-chip__text"):
          movie_genre.append(genre.text)
            
      # Story line
      for story in g.find_all('div', class_ = "ipc-html-content ipc-html-content--base"):
        storyline = story.find('div').text

      # Plot
      for plots in g.find_all('p', class_ ="sc-5f699a2-3 lopbTB"):
        plot = plots.find('span').text

    except:
      pass

  return movie_genre, storyline, plot

# %%
URL = 'https://www.imdb.com/title/tt10954984/'
imdb_scrape(URL)
# Out:
# (['Horror', 'Mystery', 'Sci-Fi'],
#  'The amount of reviews calling this pointless and terrible clearly didn\'t read much into what happens here. Peele is pointing a mirror up to you and the most ironic part is a lot of don\'t even seem to notice. No, this isn\'t a typical horror movie. It\'s more of a Spielbergian blockbuster satire with some amusing moments sprinkled throughout. The "entity" is creative and can be quite terrifying. The cinematography is top notch and probably the standout feature of the film, while Kaluuya can say an immense amount without even speaking a word. The screenplay is odd to say the least, but it hits more than it misses.While I still think this is a lesser film than Get Out or Us and it ran a little too long, you have to commend its originality in a summer sea of IP-based films. Peele attempts something profound and unique here, which should be respected regardless of your thoughts on the film.',
#  'The residents of a lonely gulch in inland California bear witness to an uncanny and chilling discovery.')

# %%
all_result = []
for ind, title in enumerate(title_df['movie']):
  print('-----------')
  print(ind, title)
  url = find_imdb_url(title)
  if url is not None:
    value = imdb_scrape(url)
    all_result.append(value)
  else:
    all_result.append(None)
# Out:
# -----------
# 0 Guardians of the Galaxy Vol 3
# -----------
# 1 Citadel
# -----------
# 2 Peter Pan  Wendy
# -----------
# 3 Dungeons  Dragons Honor Among Thieves
# -----------
# 4 Dune Part Two
# -----------
# 5 Sweet Tooth
# -----------
# 6 The Hunger Games The Ballad of Songbirds and Snakes
# -----------
# 7 Ghosted
# -----------
# 8 The Mandalorian
# -----------
# 9 Barry
# -----------
# 10 The Night Agent
# -----------
# 11 AKA
# -----------
# 12 John Wick Chapter 4
# -----------
# 13 The Rookie
# -----------
# 14 Game of Thrones
# -----------
# 15 Sisu
# -----------
# 16 The Last of Us
# -----------
# 17 The Covenant
# -----------
# 18 The Flash
# -----------
# 19 Rabbit Hole
# -----------
# 20 The Last Kingdom
# -----------
# 21 The Flash
# -----------
# 22 Star Trek Picard
# -----------
# 23 Gran Turismo
# -----------
# 24 Guardians of the Galaxy
# -----------
# 25 Dune
# -----------
# 26 Avatar The Way of Water
# -----------
# 27 AntMan and the Wasp Quantumania
# -----------
# 28 Demon Slayer Kimetsu no Yaiba
# -----------
# 29 Transformers Rise of the Beasts
# -----------
# 30 The Boys
# -----------
# 294 Saint X
# -----------
# 295 American Horror Story
# -----------
# 296 The Diplomat
# -----------
# 297 House of the Dragon
# -----------
# 298 911 Lone Star
# -----------
# 299 Vikings
# -----------
# 300 Guardians of the Galaxy Vol 3
# -----------
# 301 Succession
# -----------
# 302 Ted Lasso
# -----------
# 303 Peter Pan  Wendy
# -----------
# 304 Dungeons  Dragons Honor Among Thieves
# -----------
# 305 The Super Mario Bros Movie
# -----------
# 306 Beef
# -----------
# 307 Ghosted
# -----------
# 308 Jury Duty
# -----------
# 309 Barry
# -----------
# 310 Renfield
# -----------
# 311 Beau Is Afraid
# -----------
# 312 The Marvelous Mrs Maisel
# -----------
# 313 Mrs Davis
# -----------
# 314 Are You There God Its Me Margaret
# -----------
# 315 Shameless
# -----------
# 316 Young Sheldon
# -----------
# 317 Guardians of the Galaxy
# -----------
# 318 Its Always Sunny in Philadelphia
# -----------
# 319 Workin Moms
# -----------
# 320 AntMan and the Wasp Quantumania
# -----------
# 321 The Boys
# -----------
# 322 The White Lotus
# -----------
# 323 The Office
# -----------
# 324 Cocaine Bear
# -----------
# 325 Shrinking
# -----------
# 326 Guardians of the Galaxy Vol 2
# -----------
# 327 Everything Everywhere All at Once
# -----------
# 328 Modern Family
# -----------
# 329 Suits
# -----------
# 330 Bupkis
# -----------
# 331 Twisted Metal
# -----------
# 332 Operation Fortune Ruse de guerre
# -----------
# 333 The Big Bang Theory
# -----------
# 334 Shazam Fury of the Gods
# -----------
# 335 Friends
# -----------
# 336 A Million Little Things
# -----------
# 337 The Menu
# -----------
# 338 Love Again
# -----------
# 339 Wednesday
# -----------
# 340 SexLife
# -----------
# 341 Barbie
# -----------
# 342 Pitch Perfect
# -----------
# 343 A Man Called Otto
# -----------
# 344 Babylon
# -----------
# 345 South Park
# -----------
# 346 Bones
# -----------
# 347 Mafia Mamma
# -----------
# 348 Wish
# -----------
# 349 Ghosts
# -----------
# 350 Bullet Train
# -----------
# 351 Schmigadoon
# -----------
# 352 True Lies
# -----------
# 353 Champions
# -----------
# 354 Seinfeld
# -----------
# 355 Lucky Hank
# -----------
# 356 Tu Jhoothi Main Makkaar
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-10-f5e46b8944d6> in <cell line: 2>()
#       3   print('-----------')
#       4   print(ind, title)
# ----> 5   url = find_imdb_url(title)
#       6   if url is not None:
#       7     value = imdb_scrape(url)
#
# <ipython-input-6-7299da829ee7> in find_imdb_url(query)
#       8
#       9   hasil = []
# ---> 10   for g in soup.find_all('div', class_='g'):
#      11     anchors = g.find_all('a')
#      12     if anchors:
#
# UnboundLocalError: local variable 'soup' referenced before assignment

# %%
final_result = pd.DataFrame(all_result, columns=["Genre", "Storyline", 'plot'])

# %%
final_result
# Out:
#                            Genre  \
# 0    [Action, Adventure, Comedy]
# 1      [Action, Drama, Thriller]
# 2    [Action, Adventure, Comedy]
# 3    [Action, Adventure, Comedy]
# 4     [Action, Adventure, Drama]
# ..                           ...
# 351   [Comedy, Fantasy, Musical]
# 352   [Action, Comedy, Thriller]
# 353       [Comedy, Drama, Sport]
# 354                     [Comedy]
# 355              [Comedy, Drama]
#
#                                              Storyline  \
# 0    "There is no God. That's why I stepped in." I ...
# 1    Like others, I found the opening sequence on t...
# 2    Much of what you expect from pretty much every...
# 3    I've never played the game, and not sure if I ...
# 4
# ..                                                 ...
# 351  I'm here for keagen but it's pretty good I can...
# 352  Joining Terminator 2: Judgement Day as one of ...
# 353  Despite mixed reviews, I absolutely loved this...
# 354  The best sitcom ever to be produced and aired ...
# 355  Just watched the first episode of "Lucky Hank"...
#
#                                                   plot
# 0    Still reeling from the loss of Gamora, Peter Q...
# 1    Global spy agency Citadel has fallen, and its ...
# 2    Follow the adventures of Peter Pan, a boy who ...
# 3    A charming thief and a band of unlikely advent...
# 4    A boy becomes the Messiah of nomads on a deser...
# ..                                                 ...
# 351  A couple on a backpacking trip discovers a mag...
# 352  A fearless, globe-trotting, terrorist-battling...
# 353  A former minor-league basketball coach is orde...
# 354  The continuing misadventures of neurotic New Y...
# 355  An English department chairman at an underfund...
#
# [356 rows x 3 columns]

# %%
title_df_new = title.iloc[:356]
title_df_new
# Out:
#                                        movie
# 0             Guardians of the Galaxy Vol. 3
# 1                                    Citadel
# 2                          Peter Pan & Wendy
# 3    Dungeons & Dragons: Honor Among Thieves
# 4                             Dune: Part Two
# ..                                       ...
# 351                             Schmigadoon!
# 352                                True Lies
# 353                                Champions
# 354                                 Seinfeld
# 355                               Lucky Hank
#
# [356 rows x 1 columns]

# %%
df = pd.merge(title_df_new, final_result, left_index=True, right_index=True)
df
# Out:
#                                        movie                        Genre  \
# 0             Guardians of the Galaxy Vol. 3  [Action, Adventure, Comedy]
# 1                                    Citadel    [Action, Drama, Thriller]
# 2                          Peter Pan & Wendy  [Action, Adventure, Comedy]
# 3    Dungeons & Dragons: Honor Among Thieves  [Action, Adventure, Comedy]
# 4                             Dune: Part Two   [Action, Adventure, Drama]
# ..                                       ...                          ...
# 351                             Schmigadoon!   [Comedy, Fantasy, Musical]
# 352                                True Lies   [Action, Comedy, Thriller]
# 353                                Champions       [Comedy, Drama, Sport]
# 354                                 Seinfeld                     [Comedy]
# 355                               Lucky Hank              [Comedy, Drama]
#
#                                              Storyline  \
# 0    "There is no God. That's why I stepped in." I ...
# 1    Like others, I found the opening sequence on t...
# 2    Much of what you expect from pretty much every...
# 3    I've never played the game, and not sure if I ...
# 4
# ..                                                 ...
# 351  I'm here for keagen but it's pretty good I can...
# 352  Joining Terminator 2: Judgement Day as one of ...
# 353  Despite mixed reviews, I absolutely loved this...
# 354  The best sitcom ever to be produced and aired ...
# 355  Just watched the first episode of "Lucky Hank"...
#
#                                                   plot
# 0    Still reeling from the loss of Gamora, Peter Q...
# 1    Global spy agency Citadel has fallen, and its ...
# 2    Follow the adventures of Peter Pan, a boy who ...
# 3    A charming thief and a band of unlikely advent...
# 4    A boy becomes the Messiah of nomads on a deser...
# ..                                                 ...
# 351  A couple on a backpacking trip discovers a mag...
# 352  A fearless, globe-trotting, terrorist-battling...
# 353  A former minor-league basketball coach is orde...
# 354  The continuing misadventures of neurotic New Y...
# 355  An English department chairman at an underfund...
#
# [356 rows x 4 columns]

# %%
df.to_csv('data_film.csv', index=False)
