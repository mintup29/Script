# %% [markdown]
# ## Imports

# %%
pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)

# %%
from requests import get
from bs4 import BeautifulSoup
from warnings import warn
from time import sleep
from random import randint
import numpy as np, pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Scraping

# %% [markdown]
# ## Function Title Scraping per Genre

# %%
pages = np.arange(1, 21)

# headers = {'Accept-Language': 'en-US,en;q=0.8'} # If this is not specified, the default language is Chinese
USER_AGENT = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0"
headers = {"user-agent" : USER_AGENT, 'Accept-Language': 'en-US,en;q=0.8'}

#initialize empty lists to store the variables scraped
hrefs = []

def title(topic):
  for page in pages:
    
    # get request
    url = f"https://digilib.uns.ac.id/dokumen/search/{page}?q={topic}"
    response = get(url, headers=headers)

    sleep(randint(8,15))
    
    #throw warning for status codes that are not 200
    if response.status_code != 200:
        warn('Request: {}; Status code: {}'.format(requests, response.status_code))

    #parse the content of current iteration of request
    soup = BeautifulSoup(response.text, 'html.parser')
        
    all_links = soup.find_all('div', class_='judul')
    
    for link in all_links:
      href = link.a.get('href')
      hrefs.append(href)

# %%
topics = ['machine+learning']
for topic in topics:
  title(topic)

# %%
href = pd.DataFrame({'link': hrefs})
href
# Out:
#                                                   link
# 0    https://digilib.uns.ac.id/dokumen/detail/97633...
# 1    https://digilib.uns.ac.id/dokumen/detail/98779...
# 2    https://digilib.uns.ac.id/dokumen/detail/88107...
# 3    https://digilib.uns.ac.id/dokumen/detail/90281...
# 4    https://digilib.uns.ac.id/dokumen/detail/90628...
# ..                                                 ...
# 195  https://digilib.uns.ac.id/dokumen/detail/87649...
# 196  https://digilib.uns.ac.id/dokumen/detail/87569...
# 197  https://digilib.uns.ac.id/dokumen/detail/87643...
# 198  https://digilib.uns.ac.id/dokumen/detail/87644...
# 199  https://digilib.uns.ac.id/dokumen/detail/87603...
#
# [200 rows x 1 columns]

# %% [markdown]
# ## Scraping Content

# %%
def digilib(URL):
  # desktop user-agent
  resp = get(URL, headers= headers)

  if resp.status_code == 200:
      soup = BeautifulSoup(resp.content, "html.parser")

  table = soup.find('table')

  rows = table.find_all('tr')
  data = []
  for row in rows:
    cells = row.find_all('td')
    row_data = []
    for cell in cells:
        row_data.append(cell.text.strip())  # Extract the text content of the cell and remove any leading/trailing whitespaces
    data.append(row_data)

  df = pd.DataFrame(data)
  df = df.T

  new_header = df.iloc[0]  # Extract the first row as the new header
  df = df[1:]  # Remove the first row from the DataFrame
  df.columns = new_header  # Assign the new header to the DataFrame columns
  df = df.drop(1).reset_index(drop=True)
  columns_to_keep = ['Judul', 'Subyek', 'Abstrak', 'Pembimbing']  # Names of the columns you want to keep
  df = df.drop(df.columns.difference(columns_to_keep), axis=1)

  return df['Judul'].to_string(index=False), df['Subyek'].to_string(index=False), df['Abstrak'].to_string(index=False), df['Pembimbing'].to_string(index=False)

# %%
URL = 'https://digilib.uns.ac.id/dokumen/detail/76778/Analisis-Sentimen-Masyarakat-pada-Media-Sosial-Twitter-terhadap-Pilkada-Dki-Jakarta-2017-dengan-Pendekatan-Prediktif-dan-Deskriptif'
digilib(URL)
# Out:
# ('Analisis Sentimen Masyarakat pada Media Sosial ...',
#  'SENTIMENT ANALYSIS, NATURAL LANGUAGE PROCESSING...',
#  'ABSTRAKTujuan utama dari penelitian ini adalah ...',
#  '1. Afrizal Doewes S.Kom., M.Sc. 2. Dr. Eng Anto...')

# %%
all_result = []
for ind, url in enumerate(href['link']):
  print('-----------')
  print(ind, url)
  if url is not None:
    value = digilib(url)
    all_result.append(value)
  else:
    all_result.append(None)
# Out:
# -----------
# 0 https://digilib.uns.ac.id/dokumen/detail/97633/Identifikasi-Hipertensi-menggunakan-Heart-Rate-Variability-Fotopletismogram-dan-Algoritma-Machine-Learning
# -----------
# 1 https://digilib.uns.ac.id/dokumen/detail/98779/ANALISIS-SENTIMEN-TERKAIT-TANGGAPAN-TUDUHAN-NEGATIF-PANDEMI-ATAS-COVID-19-TERHADAP-CHINA-MELALUI-AKUN-TWITTER-ZHAO-LIJIAN-DAN-HUA-CHUNYING
# -----------
# 2 https://digilib.uns.ac.id/dokumen/detail/88107/Rasio-Keuangan-pada-Lima-Bank-di-Indonesia-dengan-Artificial-Neural-Networks
# -----------
# 3 https://digilib.uns.ac.id/dokumen/detail/90281/Model-Prediksi-Kekeringan-Menggunakan-Machine-Learning-Kasus-di-Kabupaten-Wonogiri
# -----------
# 4 https://digilib.uns.ac.id/dokumen/detail/90628/Tinjauan-Teknis-Studi-Supervised-Machine-Learning-dan-Implementasinya-pada-Aplikasi-Herbify-untuk-Dataset-Tanaman-Herbal
# -----------
# 5 https://digilib.uns.ac.id/dokumen/detail/93157/Pengaruh-Variabel-Bebas-dalam-Analisis-Kapasitas-Dukung-dan-Penurunan-Fondasi-Tiang-Menggunakan-Correlation-Based-Feature-Selection-CFS
# -----------
# 6 https://digilib.uns.ac.id/dokumen/detail/93765/Deteksi-Myocardial-Infraction-Menggunakan-Fitur-Statistik-Segmen-ST-Elektrokardiogram-dan-Algoritma-Machine-Learning
# -----------
# 7 https://digilib.uns.ac.id/dokumen/detail/94317/PREDIKSI-HARGA-BITCOIN-BERDASARKAN-SENTIMEN-SOSIAL-DAN-HISTORICAL-PRICE-MENGGUNAKAN-LONG-SHORT-TERM-MEMMORY-LSTM
# -----------
# 8 https://digilib.uns.ac.id/dokumen/detail/94343/Implementasi-Deep-Neural-Network-dalam-Perancangan-Respons-Chatbot-dengan-Menggunakan-Pendekatan-Natural-Language-Processing
# -----------
# 9 https://digilib.uns.ac.id/dokumen/detail/95040/Rekognisi-Masker-Wajah-Menggunakan-Deep-Learning-dengan-Arsitektur-MobilenetV2-untuk-Memantau-Pengunaan-Masker-Sesuai-Protokol-Kesehatan-Studi-Kasus-SD-Negeri-Aren-Jaya-VII-Bekasi
# -----------
# 10 https://digilib.uns.ac.id/dokumen/detail/95684/Peramalan-Triase-Pasien-Instalasi-Gawat-Darurat-IGD-Menggunakan-Pendekatan-Klasifikasi-Machine-Learning-Studi-Kasus-Rumah-Sakit-UNS
# -----------
# 11 https://digilib.uns.ac.id/dokumen/detail/86250/Pengenalan-Bahasa-Isyarat-ASL-American-Sign-Language-menggunakan-Convolutional-Neural-Network-dan-Mediapipe-Hand-Tracking
# -----------
# 12 https://digilib.uns.ac.id/dokumen/detail/86487/Pengaruh-Double-Learning-Logistic-Regression-pada-Klasifikasi-Data-Liver
# -----------
# 13 https://digilib.uns.ac.id/dokumen/detail/89289/Rancang-Bangun-Laboratorium-Virtual-Berbasis-Private-Cloud-Dengan-Model-Layanan-IAAS-Sebagai-Media-Praktikum-Jaringan-Komputer
# -----------
# 14 https://digilib.uns.ac.id/dokumen/detail/94556/Estimasi-Remaining-Useful-Life-RUL-Baterai-Lithium-Ion-Berbasis-Machine-Learning
# -----------
# 15 https://digilib.uns.ac.id/dokumen/detail/80497/Deteksi-Penyakit-Tanaman-Tomat-Melalui-Tekstur-Daun-Dengan-Metode-Gabor-Filter
# -----------
# 16 https://digilib.uns.ac.id/dokumen/detail/80496/Modifikasi-Algoritma-Density-Based-Spatial-Clustering-of-Applications-With-Noise-Dbscan-Untuk-Reduksi-Data-Pada-Intrusion-Detection-Evaluation-Dataset
# -----------
# 17 https://digilib.uns.ac.id/dokumen/detail/77350/Undersampling-Majority-Class-pada-Kasus-Imbalanced-Dataset-dan-Aplikasinya-Pada-Deteksi-Anomali-Transaksi-Kartu-Kredit
# -----------
# 18 https://digilib.uns.ac.id/dokumen/detail/58678/Batik-Images-Retrieval-Menggunakan-Convolutional-Neural-Network-dengan-Metode-Supervised-dan-Unsupervised-Learning
# -----------
# 19 https://digilib.uns.ac.id/dokumen/detail/59019/Prediksi-Rating-Produk-Kosmetik-Berdasarkan-Teks-Review-Pada-Website-Female-Daily-Menggunakan-Metode-Naïve-Bayes-Classifier
# -----------
# 20 https://digilib.uns.ac.id/dokumen/detail/76778/Analisis-Sentimen-Masyarakat-pada-Media-Sosial-Twitter-terhadap-Pilkada-Dki-Jakarta-2017-dengan-Pendekatan-Prediktif-dan-Deskriptif
# -----------
# 21 https://digilib.uns.ac.id/dokumen/detail/51198/Upaya-Meningkatkan-Motivasi-Belajar-dan-Hasil-Praktik-Mesin-Bubut-Melalui-Perancangan-Work-Preparation-Siswa-Kelas-XI-Pemesinan-SMK-PGRI-1-Surakarta-Tahun-Pelajaran-20142015
# -----------
# 22 https://digilib.uns.ac.id/dokumen/detail/45739/Penggunaan-Model-Visual-Auditory-Kinesthetic-VAK-dengan-Multimedia-dalam-Peningkatan-Pembelajaran-IPA-Tentang-Pesawat-Sederhana-pada-Siswa-Kelas-V-SDN-1-Kuwarasan-Tahun-Ajaran-20142015
# -----------
# 23 https://digilib.uns.ac.id/dokumen/detail/48755/Penerapan-Media-Flip-Book-pada-Pembelajaran-Pesawat-Sederhana-untuk-Siswa-SMP-Kelas-VIII-B-SMP-Islam-Diponegoro-Surakarta
# -----------
# 24 https://digilib.uns.ac.id/dokumen/detail/38000/Voltage-Problem-Location-Using-Support-Vector-Machine
# -----------
# 25 https://digilib.uns.ac.id/dokumen/detail/28903/Proses-pembuatan-jamu-sediaan-serbuk-di-PT-Gujati-59-Utama-jl-raya-solo-wonogiri-no59-km-265-desa-Gupit-kecamatan-Nguter-kabupaten-Sukoharjo
# -----------
# 26 https://digilib.uns.ac.id/dokumen/detail/70495/Mekanisme-transmisi-pada-herbal-crystallization-machine-dengan-memanfaatkan-motor-listrik-sebagai-sumber-daya
# -----------
# 27 https://digilib.uns.ac.id/dokumen/detail/98604/PEMBERDAYAAN-MASYARAKAT-MELALUI-PENDIDIKAN-NONFORMAL-KEWIRAUSAHAAN-UNTUK-KEMANDIRIAN-UMKM
# -----------
# 28 https://digilib.uns.ac.id/dokumen/detail/98912/Pengaruh-Media-Website-Bioenial-Biology-Electronic-Activity-based-Learning-terhadap-Keterampilan-Proses-Sains-dan-Kemampuan-Metakognisi-Siswa-Kelas-XI-pada-Materi-Sistem-Gerak
# -----------
# 29 https://digilib.uns.ac.id/dokumen/detail/100144/PENGARUH-MODEL-PEMBELAJARAN-PROBLEM-BASED-LEARNING-DAN-PROJECT-BASED-LEARNING-UNTUK-MENINGKATKAN-HASIL-BELAJAR-EKONOMI-SISWA-SMA-SCIENCE-PLUS-BAITUL-QURAN-BOARDING-SCHOOL-SAMBIREJO-DITINJAU-DARI-KEMAMPUAN-BERPIKIR-KREATIF
# -----------
# 30 https://digilib.uns.ac.id/dokumen/detail/100854/Pengaruh-Media-Aplikasi-Augmented-Reality-AR-Berbasis-Multipel-Representasi-dengan-Model-Discovery-Learning-terhadap-Keterampilan-Proses-Sains-dan-Hasil-Belajar-Kognitif-Siswa-pada-Materi-Ikatan-Kimia-Kelas-X-SMA-N-3-Surakarta
# -----------
# 31 https://digilib.uns.ac.id/dokumen/detail/98418/EXPLORING-THE-POTENTIAL-OF-GOOGLE-DOCS-IN-FACILITATING-PEER-FEEDBACK-IN-AN-EFL-ACADEMIC-WRITING-COURSE-An-Autobiography-Narrative-Inquiry-of-Pre-Service-English-Teachers-Perspective
# -----------
# 32 https://digilib.uns.ac.id/dokumen/detail/98450/PENGARUH-KOMUNIKASI-INTERPERSONAL-DAN-SELF-REGULATED-LEARNING-TERHADAP-HASIL-BELAJAR-SISWA-UNTUK-MATA-PELAJARAN-EKONOMI-DAN-BISNIS-PADA-SISWA-SMK-NEGERI-DI-KLATEN
# -----------
# 33 https://digilib.uns.ac.id/dokumen/detail/98717/Klasifikasi-Indeks-Pembangunan-Manusia-KabupatenKota-di-Indonesia-dengan-Metode-Random-Forest-dan-Support-Vector-Machine
# -----------
# 34 https://digilib.uns.ac.id/dokumen/detail/98466/PENGEMBANGAN-BAHAN-AJAR-MATEMATIKA-BERBASIS-PROBLEM-BASED-LEARNING-PBL-UNTUK-MENINGKATKAN-KEMAMPUAN-PEMECAHAN-MASALAH-MATEMATIKA-PADA-MATERI-MATRIKS-KELAS-XI-SMA-ISLAM-1-SURAKARTA-TAHUN-AJARAN-20222023
# -----------
# 35 https://digilib.uns.ac.id/dokumen/detail/98392/Survei-Proses-Pembelajaran-Pendidikan-Jasmani-Olahraga-dan-Kesehatan-Pada-Pandemi-Covid-19-Di-SMP-Negeri-1-Banyudono-Tahun-Pelajaran-20212022
# -----------
# 36 https://digilib.uns.ac.id/dokumen/detail/98417/KOMPARASI-MODEL-PEMBELAJARAN-FLIPPED-CLASSROOM-DAN-DISCOVERY-LEARNING-DITINJAU-DARI-KEMANDIRIAN-BELAJAR-TERHADAP-KEMAMPUAN-BERPIKIR-KRITIS-SISWA-PADA-MATA-PELAJARAN-EKONOMI-DI-SMAN-KOTA-SRAGEN
# -----------
# 37 https://digilib.uns.ac.id/dokumen/detail/98406/Pengembangan-Modul-Elektronik-Fisika-Berbasis-Saintifik-Menggunakan-Exe-Learning-V-251-pada-Materi-Pemanasan-Global
# -----------
# 38 https://digilib.uns.ac.id/dokumen/detail/98323/IMPLEMENTASI-PROGRAM-LITERASI-MEMBACA-PADA-PEMBELAJARAN-BAHASA-INDONESIA-DI-SEKOLAH-PENGGERAKSTUDI-KASUS-DI-SMP-WARGA-SURAKARTA
# -----------
# 39 https://digilib.uns.ac.id/dokumen/detail/98144/IMPLEMENTASI-KURIKULUM-SMK-PUSAT-KEUNGGULAN-STUDI-KASUS-DI-SEKOLAH-MENENGAH-KEJURUAN-NEGERI-2-SALATIGA-TAHUN-PELAJARAN-20212022
# -----------
# 40 https://digilib.uns.ac.id/dokumen/detail/98286/PENGARUH-MODEL-PROBLEM-BASED-LEARNING-TERHADAP-KEMAMPUAN-BERPIKIR-KREATIF-DAN-HASIL-BELAJAR-KOGNITIF-SISWA-KELAS-VIII-PADA-MATERI-SISTEM-GERAK-MANUSIA
# -----------
# 41 https://digilib.uns.ac.id/dokumen/detail/97234/ANALISIS-PENERAPAN-METODE-PEMBELAJARAN-DARING-BERBASIS-MICROSOFT-TEAMS-TERHADAP-PESERTA-DIDIK-KELAS-12-MATA-PELAJARAN-DESAIN-MULTIMEDIA-INTERAKTIF-DI-SMK-BATIK-2-SURAKARTA
# -----------
# 42 https://digilib.uns.ac.id/dokumen/detail/97319/Pengembangan-Modul-PEMBELAJARAN-FISIKA-BERBASIS-PROYEK-PROJECT-BASED-LEARNING-MATERI-SUHU-KALOR-DAN-PERPINDAHAN-UNTUK-MENINGKATKAN-KREATIVITAS-BELAJAR-DAN-KEMAMPUAN-LITERASI-SAINS-SISWA-SMAMA
# -----------
# 43 https://digilib.uns.ac.id/dokumen/detail/98380/Analisis-Sentimen-pada-Twitter-Terhadap-Kinerja-Pemerintahan-Presiden-Joko-Widodo-Menggunakan-Algoritma-Naive-Bayes-Classifier-K-Nearest-Neighbors-dan-Support-Vector-Machine
# -----------
# 44 https://digilib.uns.ac.id/dokumen/detail/97293/An-Analysis-of-Pre-service-Teachers-Experience-in-Teaching-Writing-Analytical-Exposition-Text-An-Autobiographical-Narrative-Inquiry-Study-at-One-of-the-State-Senior-High-Schools-in-Kartasura-in-the-Academic-Year-of-20212022
# -----------
# 45 https://digilib.uns.ac.id/dokumen/detail/97435/ANALISIS-WACANA-KRITIS-DAN-NILAI-MORAL-DALAM-NASKAH-HUKUM-ADAT-TANAH-BIMA-DAN-PEMANFAATANNYA-DALAM-PERKULIAHAN-ANALISIS-WACANA-DI-PERGURUAN-TINGGI
# -----------
# 46 https://digilib.uns.ac.id/dokumen/detail/97442/EFEKTIVITAS-MEDIA-PEMBELAJARAN-MENGGUNAKAN-APLIKASI-KAHOOT-MELALUI-MODEL-PEMBELAJARAN-PROBLEM-BASED-LEARNING-TERHADAP-HASIL-BELAJAR-SISWA-GEOGRAFI-KELAS-X-SMA-NEGERI-2-BANTUL-TAHUN-AJARAN-20212022
# -----------
# 47 https://digilib.uns.ac.id/dokumen/detail/97626/Perancangan-Form-Manajemen-Risiko-pada-Praktikum-Perancangan-Teknik-Industri2-Menggunakan-Pendekatan-Sistem-Man-Machine-Environment
# -----------
# 48 https://digilib.uns.ac.id/dokumen/detail/97790/Pengaruh-Model-Pembelajaran-Argument-Driven-Inquiry-terhadap-Kemampuan-Argumentasi-Ilmiah-Siswa-SMP-pada-Materi-Usaha-dan-Pesawat-Sederhana
# -----------
# 49 https://digilib.uns.ac.id/dokumen/detail/97876/Pengembangan-Media-Pembelajaran-Berbasis-Aplikasi-Mobile-Augmented-Reality-dengan-Pendekatan-Saintifik-pada-Materi-Fluida-Statis
# -----------
# 50 https://digilib.uns.ac.id/dokumen/detail/98068/PENGARUH-MODEL-PROJECT-BASED-LEARNING-TERINTEGRASI-PENDEKATAN-STEM-TERHADAP-KEMAMPUAN-BERPIKIR-KRITIS-SISWA-PADA-PEMBELAJARAN-IPA-SMP
# -----------
# 51 https://digilib.uns.ac.id/dokumen/detail/98086/Analisis-Kelengkapan-Pengisian-Informed-Consent-Di-Rumah-Sakit-Umum-Bhakti-Husada-Krikilan-Banyuwangi
# -----------
# 52 https://digilib.uns.ac.id/dokumen/detail/98203/Pengembangan-Model-Discovery-Learning-Berbasis-Mobile-Untuk-Meningkatkan-Keterampilan-Abad-21-Pada-Sekolah-Menengah-Kejuruan
# -----------
# 53 https://digilib.uns.ac.id/dokumen/detail/98136/IMPLEMENTASI-NILAI-TOLERANSI-DALAM-PEMBELAJARAN-SEJARAH-DI-SMA-REGINA-PACIS-SURAKARTA-TAHUN-AJARAN-20202021
# -----------
# 54 https://digilib.uns.ac.id/dokumen/detail/98484/Pre-Service-EFL-Teachers-Use-of-Reinforcement-during-Teaching-Practicum
# -----------
# 55 https://digilib.uns.ac.id/dokumen/detail/98577/Pengaruh-Model-Pembelajaran-Problem-Based-Learning-PBL-dan-Double-Loop-Problem-Solving-DLPS-pada-Materi-Pencemaran-Lingkungan-terhadap-Kemampuan-Pemecahan-Masalah-ditinjau-dari-Berpikir-Kritis-dan-Berpikir-Kreatif-Siswa-Kelas-VII
# -----------
# 56 https://digilib.uns.ac.id/dokumen/detail/98527/Pengembangan-Bahan-Ajar-Berbantuan-Flip-PDF-Professional-Berbasis-Self-Determined-Learning-Model-of-Instruction-untuk-Meningkatkan-Kemampuan-Pemecahan-Masalah-Matematika-pada-Materi-Aritmetika-Sosial
# -----------
# 57 https://digilib.uns.ac.id/dokumen/detail/98580/Students-Perception-of-Extramural-Informal-Digital-Learning-of-English-IDLE-towards-Communicative-Competence
# -----------
# 58 https://digilib.uns.ac.id/dokumen/detail/98620/PENGARUH-MODEL-PEMBELAJARAN-CONCEPT-ATTAINMENT-DENGAN-METODE-RESITASI-TERHADAP-HASIL-BELAJAR-MATERI-LAJU-REAKSI-DITINJAU-DARI-KECERDASAN-EMOSIONAL-SISWA-KELAS-XI-SMA-NEGERI-1-SURAKARTA
# -----------
# 59 https://digilib.uns.ac.id/dokumen/detail/98623/PENGARUH-MODEL-LEARNING-CYCLE-5E-BERBANTUAN-APLIKASI-CROCODILE-CHEMISTRY-TERHADAP-PRESTASI-BELAJAR-SISWA-KELAS-XI-PADA-MATERI-LAJU-REAKSI
# -----------
# 60 https://digilib.uns.ac.id/dokumen/detail/98662/Penerapan-Learning-Factory-pada-Redesign-Stasiun-Kerja-Welding-Praktikum-Perancangan-Teknik-Industri-2-Menggunakan-Metode-Pughs-untuk-Memperbaiki-Postur-Kerja
# -----------
# 61 https://digilib.uns.ac.id/dokumen/detail/98766/Penggunaan-Media-Sempoa-Untuk-Meningkatkan-Kemampuan-Berhitung-Penjumlahan-Pada-Siswa-Tunagrahita-Kelas-2-SDLB-Negeri-Jepara
# -----------
# 62 https://digilib.uns.ac.id/dokumen/detail/98686/Pre-service-Teachers-Self-efficacy-in-Technology-Integration-of-Computer-Assisted-Language-Learning-in-English-Language-Teaching-A-Case-Study
# -----------
# 63 https://digilib.uns.ac.id/dokumen/detail/98689/SYNCHRONOUS-COMPUTER-MEDIATED-COMMUNICATION-VS-FACE-TO-FACE-INTERACTION-EFL-STUDENTS-PERCEPTION-ON-SPEAKING-ANXIETY
# -----------
# 64 https://digilib.uns.ac.id/dokumen/detail/98713/Pre-Service-Teachers-Reflection-on-action-of-Their-Cyclical-Self-Assessment-Process-in-Academic-Writing-Mediated-by-Scribo-A-Narrative-Inquiry
# -----------
# 65 https://digilib.uns.ac.id/dokumen/detail/98735/Klasifikasi-Penyakit-Diabetes-Menggunakan-Algoritma-Random-Forest-dan-Support-Vector-Machine
# -----------
# 66 https://digilib.uns.ac.id/dokumen/detail/98749/The-effects-of-massed-and-distributed-drills-muscle-strength-andintelligence-quotients-towards-tennis-groundstroke-skills-of-sportstudents
# -----------
# 67 https://digilib.uns.ac.id/dokumen/detail/98784/PENGARUH-MODEL-PEMBELAJARAN-PROBLEM-BASED-LEARNING-DAN-GUIDE-INQUIRY-TERHADAP-PRESTASI-BELAJAR-KOGNITIF-AKUNTANSI-SISWA-KELAS-X-AKUNTANSI-DAN-KEUANGAN-LEMBAGA-SMK-WIKARYA-KARANGANYAR
# -----------
# 68 https://digilib.uns.ac.id/dokumen/detail/98850/Dampak-Pembelajaran-Daring-Terhadap-Potensi-Learning-Loss-Siswa-Sd-N-Cacaban-4-Kota-Magelang-Di-Masa-Pandemi-Covid-19
# -----------
# 69 https://digilib.uns.ac.id/dokumen/detail/98971/IOT-BASED-DC-POWER-LOGGER-AND-ITS-POTENTIAL-FOR-DYNAMICS-ELECTRICITY-LEARNING
# -----------
# 70 https://digilib.uns.ac.id/dokumen/detail/98974/Efektivitas-Model-Pembelajaran-Blended-Learning-Tipe-Flipped-Classroom-pada-Mata-Pelajaran-Dasar-Desain-Grafis-di-SMK-Amaliah-Bogor
# -----------
# 71 https://digilib.uns.ac.id/dokumen/detail/98997/Pengaruh-Model-Discovery-Learning-berbantuan-Media-Game-Quizizz-terhadap-Kompetensi-Pengetahuan-IPA-dan-Motivasi-Belajar-Siswa-Kelas-VII
# -----------
# 72 https://digilib.uns.ac.id/dokumen/detail/99010/PENGARUH-CARD-GAME-ONLINE-SISTEM-GERAK-MOVE-ON-SKUY-BERBANTU-VIDEO-TERHADAP-PEMAHAMAN-KONSEP-SISWA-KELAS-XI
# -----------
# 73 https://digilib.uns.ac.id/dokumen/detail/99023/EKSPERIMENTASI-MODEL-PEMBELAJARAN-PROBLEM-BASED-LEARNING-DENGAN-MEDIA-WEB-GOOGLE-SITES-PADA-MATERI-PROGRAM-LINEAR-DITINJAU-DARI-GAYA-BELAJAR-SISWA-KELAS-X-SMK-NEGERI-1-SAWIT-BOYOLALI-TAHUN-AJARAN-20222023
# -----------
# 74 https://digilib.uns.ac.id/dokumen/detail/99030/Survey-Pemahaman-Konsep-Nutrisi-Berbasis-Learning-Progression-Pada-Siswa-Sekolah-Menengah-Pertama
# -----------
# 75 https://digilib.uns.ac.id/dokumen/detail/99337/STRATEGI-PENGEMBANGAN-SUMBER-DAYA-MANUSIA-UNTUK-MENINGKATKAN-KUALITAS-PELAYANAN-PUBLIK-DI-KOTA-DILI
# -----------
# 76 https://digilib.uns.ac.id/dokumen/detail/99160/PENGEMBANGAN-MEDIA-MOBILE-LEARNING-BERBASIS-GAMIFICATION-PADA-MATERI-DINAMIKA-HIDROSFER-DAN-DAMPAKNYA-UNTUK-MENINGKATKAN-HASIL-BELAJAR-SISWA-SEKOLAH-MENENGAH-ATAS
# -----------
# 77 https://digilib.uns.ac.id/dokumen/detail/99184/Pengembangan-Media-Game-Based-Learning-Untuk-Meningkatkan-Kemampuan-Berpikir-Komputasi-Pada-Pembelajaran-Informatika-Madrasah-Tsanawiyah
# -----------
# 78 https://digilib.uns.ac.id/dokumen/detail/99191/A-CASE-STUDY-OF-PRONUNCIATION-LEARNING-STRATEGIES-OF-PROFICIENT-EFL-COLLEGE-STUDENTS
# -----------
# 79 https://digilib.uns.ac.id/dokumen/detail/99260/Pengembangan-LKPD-Berbasis-Problem-Based-Learning-PBL-untuk-Meningkatkan-Kemampuan-Pemecahan-Masalah-pada-Materi-Limit-Fungsi-Aljabar-Kelas-XII-SMK-Kristen-1-Surakarta
# -----------
# 80 https://digilib.uns.ac.id/dokumen/detail/99373/PENINGKATAN-HASIL-BELAJAR-EKONOMI-MELALUI-MODEL-CONTEXTUAL-TEACHING-AND-LEARNING-BERBASIS-METODE-EDUTAINMENT-PADA-SISWA-KELAS-XI-SMAN-1-GOMBONG
# -----------
# 81 https://digilib.uns.ac.id/dokumen/detail/99388/Pengambangan-Lembar-Kerja-Peserta-Didik-Elektronik-E-LKPD-Berbasis-Problem-Based-Learning-PBL-Untuk-Meningkatkan-Keterampilan-Literasi-Matematika-Siswa-Sekolah-Dasar-di-Banyuwangi
# -----------
# 82 https://digilib.uns.ac.id/dokumen/detail/99405/PENGEMBANGAN-BUKU-DIGITAL-SEJARAH-TOKOH-SIDO-ING-REJEK-DENGAN-MODEL-PROBLEM-BASED-LEARNING-UNTUK-MENINGKATKAN-KESADARAN-SEJARAH-PESERTA-DIDIK-SMA-NEGERI-DI-KECAMATAN-SAKO-PALEMBANG
# -----------
# 83 https://digilib.uns.ac.id/dokumen/detail/99409/Pengembangan-Modul-Digital-Sejarah-Lokal-Riau-Berbasis-Contextual-Teaching-And-Learning-CTL-Untuk-Meningkatkan-Sikap-Toleransi-Peserta-Didik-di-Sma-4-Dan-Sma-8-Kota-Pekanbaru
# -----------
# 84 https://digilib.uns.ac.id/dokumen/detail/99465/PENGEMBANGAN-MEDIA-PEMBELAJARAN-BERBASIS-GAME-BASED-LEARNING-UNTUK-MENINGKATKAN-KEMAMPUAN-KEAKSARAAN-AWAL-PESERTA-DIDIK-KELOMPOK-B-TK-KABUPATEN-KARANGANYAR
# -----------
# 85 https://digilib.uns.ac.id/dokumen/detail/99466/PENGARUH-PENGGUNAAN-MEDIA-INSTAGRAM-PADA-MODEL-PEMBELAJARAN-PROJECT-BASED-LEARNING-TERINTEGRASI-STEM-PJBL-STEM-TERHADAP-HASIL-BELAJAR-DAN-KEMAMPUAN-BERPIKIR-KREATIF-SISWA-MATERI-LAJU-REAKSI-KELAS-XI-MIPA-SMA-NEGERI-3-SUKOHARJO
# -----------
# 86 https://digilib.uns.ac.id/dokumen/detail/99523/Analysis-of-Secondary-Education-Teachers-Questioning-Strategies-during-Online-Classroom-Interaction
# -----------
# 87 https://digilib.uns.ac.id/dokumen/detail/99532/PENGEMBANGAN-TEKNOLOGI-E-LEARNING-DALAM-PERANCANGAN-DAN-PEMBUATAN-MODUL-PEMBELAJARAN-BERBASIS-E-BOOK-PADA-MATA-PELAJARAN-TEKNIK-AUDIO-VIDEO-UNTUK-MENINGKATKAN-KREATIVITAS-BELAJAR-SISWA
# -----------
# 88 https://digilib.uns.ac.id/dokumen/detail/99706/Exploring-Undergraduate-Students-Peer-Assessment-Practice-in-Academic-Writing-Facilitated-by-Artificial-Intelligence-Tools
# -----------
# 89 https://digilib.uns.ac.id/dokumen/detail/99720/PENGARUH-PENGGUNAAN-MEDIA-PEMBELAJARAN-DAN-TINGKAT-KETERAMPILAN-BERPIKIR-KRITIS-TERHADAP-HASIL-BELAJAR-SISWA-KELAS-X-MIPA-DI-SMA-NEGERI-6-SURAKARTA-PADA-MATERI-STOIKIOMETRI
# -----------
# 90 https://digilib.uns.ac.id/dokumen/detail/99722/Penerapan-Problem-Based-Learning-PBL-dengan-Media-Audiovisual-untuk-Meningkatkan-Hasil-Belajar-Siswa-Kelas-XI-IPS-2-SMAN-1-Wonosobo-Mata-Pelajaran-Ekonomi
# -----------
# 91 https://digilib.uns.ac.id/dokumen/detail/99818/COLOR-EMBEDDED-GRAYSCALE-IMAGE-MENGGUNAKAN-RESIDUAL-ATTENTION-NETWORK
# -----------
# 92 https://digilib.uns.ac.id/dokumen/detail/99820/DETEKSI-BANGUNAN-OTOMATIS-DARI-CITRA-SATELIT-BERESOLUSI-TINGGI-MENGGUNAKAN-GENERATIVE-ADVERSARIAL-NETWORK
# -----------
# 93 https://digilib.uns.ac.id/dokumen/detail/99840/Pengembangan-Model-Pembelajaran-Contextual-Teaching-and-Learning-berbasis-Multimedia-Kit-untuk-Meningkatkan-Hasil-Belajar-Peserta-Didik-Jurusan-Bisnis-Daring-dan-Pemasaran-Sekolah-Menengah-Kejuruan-di-Surakarta
# -----------
# 94 https://digilib.uns.ac.id/dokumen/detail/99947/HUBUNGAN-ANTARA-SELF-REGULATED-LEARNING-DENGAN-KECEMASAN-AKADEMIK-PADA-PESERTA-DIDIK-KELAS-X-SMK-PGRI-1-SURAKARTA
# -----------
# 95 https://digilib.uns.ac.id/dokumen/detail/99886/Pengembangan-Buku-Cerita-Bergambar-Digital-Berbasis-Karakter-Tokoh-Wayang-Punokawan-Untuk-Pembelajaran-Keterampilan-Menulis-Deskripsi-di-Sekolah-Dasar-Kabupaten-Sukoharjo
# -----------
# 96 https://digilib.uns.ac.id/dokumen/detail/99957/EFEKTIVITAS-MODEL-PEMBELAJARAN-TEAM-PROJECT-BASED-FLIP-CLASSROOM-DALAM-MENINGKATKAN-KEMAMPUAN-KOLABORASI-SISWA-SMK
# -----------
# 97 https://digilib.uns.ac.id/dokumen/detail/100050/Pengaruh-Model-Problem-Based-Learning-dengan-Media-Mind-Mapping-terhadap-Peningkatan-Hasil-Belajar-Ekonomi-Siswa-di-SMA-Negeri-1-Pulokulon-Kabupaten-Grobogan
# -----------
# 98 https://digilib.uns.ac.id/dokumen/detail/100030/MODEL-PEMBELAJARAN-APBL-ADVANCE-PROBLEM-BASED-LEARNING-UNTUK-MEMBERDAYAKAN-KEMAMPUAN-LITERASI-KIMIA-PADA-SISWA-SMAMA
# -----------
# 99 https://digilib.uns.ac.id/dokumen/detail/100033/Penerapan-Model-Problem-Based-Learning-PBL-dengan-Media-Lectora-Inspire-untuk-Meningkatkan-Hasil-Belajar-IPA-tentang-Panas-dan-Perpindahannya-pada-Siswa-Kelas-VA-SD-Negeri-2-Kebulusan-Tahun-Ajaran-20222023
# -----------
# 100 https://digilib.uns.ac.id/dokumen/detail/100087/Penerapan-Model-Problem-Based-Learning-Menggunakan-Media-Kartu-Bergambar-untuk-Meningkatkan-Komunikasi-Siswa-Kelas-V-SD-Negeri-Sidoharjo-Pada-Tema-5-Subtema-2-Materi-Jaring-jaring-Makanan-Tahun-Ajaran-20222023
# -----------
# 101 https://digilib.uns.ac.id/dokumen/detail/100055/PENGEMBANGAN-E-MODUL-BERBASIS-EXPERIENTIAL-LEARNINGUNTUK-MENINGKATKAN-PEMAHAMAN-PENGETAHUAN-CONCIERGE-SISWA-PADA-PEMBELAJARAN-FRONT-OFFICE-DI-SMK-NEGERI-1-MAGETAN
# -----------
# 102 https://digilib.uns.ac.id/dokumen/detail/100110/Pengembangan-Augmented-Reality-berbasis-Active-Learning-untuk-Meningkatkan-Literasi-Sains-dalam-Mata-Kuliah-Ilmu-Hayat-di-Sekolah-Tinggi-Ilmu-Al-Quran-dan-Sains-Al-Ishlah
# -----------
# 103 https://digilib.uns.ac.id/dokumen/detail/100135/Pengembangan-Media-Pembelajaran-Fisika-berbasis-Android-dengan-Pendekatan-Scientific-pada-Materi-Usaha-dan-Energi
# -----------
# 104 https://digilib.uns.ac.id/dokumen/detail/100181/Peningkatan-Sikap-Nasionalisme-Terintegrasi-Karakter-Moh-Hatta-melalui-Model-PBL-di-Kelas-11-IPS-1-SMAN-1-Tulakan-Kabupaten-Pacitan-Tahun-Ajaran-20222023
# -----------
# 105 https://digilib.uns.ac.id/dokumen/detail/100188/Pengembangan-Media-Pembelajaran-Android-Berbasis-Problem-Based-Learning-dengan-Android-Studio-pada-Materi-Getaran-Harmonis-Sederhana
# -----------
# 106 https://digilib.uns.ac.id/dokumen/detail/100195/Pengembangan-Bahan-Ajar-Digital-Sejarah-Perkebunan-Karet-PTPN-VII-Lampung-Berbasis-Experiential-Learning-untuk-Meningkatkan-Sikap-Kewirausahaan-Peserta-Didik-SMK-Negeri-5-Bandar-Lampung
# -----------
# 107 https://digilib.uns.ac.id/dokumen/detail/100280/PENGARUH-MODEL-PEMBELAJARAN-PROBLEM-BASED-LEARNING-BERBASIS-SOSIOSCIENTIFIC-ISSUES-SSI-TERHADAP-KEMAMPUAN-BERPIKIR-KRITIS-DAN-HASIL-BELAJAR-KOGNITIF-SISWA-PADA-MATERI-KOLOID-KELAS-XI-SMA-N-1-NGEMPLAK
# -----------
# 108 https://digilib.uns.ac.id/dokumen/detail/100367/INPUT-PROVISION-IN-LANGUAGE-LEARNING-A-NARRATIVE-INQUIRY-OF-PRE-SERVICE-TEACHER-EXPERIENCE-DURING-TEACHING-PRACTICUM
# -----------
# 109 https://digilib.uns.ac.id/dokumen/detail/100313/PENINGKATAN-HASIL-BELAJAR-IPA-TENTANG-PENGARUH-KALOR-TERHADAP-PERUBAHAN-SUHU-DAN-WUJUD-BENDA-MELALUI-MODEL-GUIDED-INQUIRY-BASED-LEARNING-DENGAN-MEDIA-KONKRET-DI-KELAS-V-SDN-2-TAMANWINANGUN-TAHUN-AJARAN-20222023
# -----------
# 110 https://digilib.uns.ac.id/dokumen/detail/100391/PEMBELAJARAN-PEMBUATAN-KERAMIK-BERBASIS-EXPERIENTAL-LEARNING-Studi-Kasus-di-Lukita-Ceramic-Studio-Yogjakarta
# -----------
# 111 https://digilib.uns.ac.id/dokumen/detail/100388/Pengembangan-Subject-Specific-Pedagogy-Ssp-Blended-Learning-Berbasis-Multiple-Representasi-Untuk-Meningkatkan-Keterampilan-Pemecahan-Masalah-Siswa-Kelas-Xi-Pada-Materi-Sistem-Koloid
# -----------
# 112 https://digilib.uns.ac.id/dokumen/detail/100418/The-Effectiveness-of-Using-Small-Group-Discussiom-Technique-To-Improve-Students-Reading-Skill
# -----------
# 113 https://digilib.uns.ac.id/dokumen/detail/100447/Analisis-Penggunaan-Media-Pembelajaran-Ditinjau-dari-Perspektif-Self-Directed-Learning-SDL-di-Kelas-IV-SD-Negeri-Kadiluwih-Tahun-Ajaran-20222023
# -----------
# 114 https://digilib.uns.ac.id/dokumen/detail/100530/PEMBELAJARAN-BAHASA-MANDARIN-DENGAN-METODE-STUDENT-CENTERED-LEARNING-DALAM-JARINGAN-GOOGLE-MEET-DI-SMAN-4-SURAKARTA
# -----------
# 115 https://digilib.uns.ac.id/dokumen/detail/100534/Pengembangan-E-Book-Berbasis-Kurikulum-Merdeka-untuk-Meningkatkan-Kemampuan-Berpikir-Kritis-Mata-Pelajaran-Matematika-Kelas-XI-Siswa-SMK-Wonogiri
# -----------
# 116 https://digilib.uns.ac.id/dokumen/detail/100541/Hubungan-antara-Self-Regulated-Learning-SRL-dengan-Prokrastinasi-Akademik-pada-Peserta-Didik-Kelas-di-XI-SMK-Pancasila-Surakarta
# -----------
# 117 https://digilib.uns.ac.id/dokumen/detail/100781/Analisis-Keterampilan-Berpikir-Kritis-Peserta-Didik-pada-Pembelajaran-Hukum-Dasar-Kimia-dengan-Pendekatan-Social-Emotional-Learning-dan-Model-Guided-Discovery-Learning-di-SMA-Batik-1-Surakarta
# -----------
# 118 https://digilib.uns.ac.id/dokumen/detail/100770/Interpersonal-Motivation-Inside-a-Digital-Game-Community-of-Practice-as-an-Extramural-Informal-Digital-Learning-of-English-Activity
# -----------
# 119 https://digilib.uns.ac.id/dokumen/detail/100664/Pembelajaran-Teks-Eksplanasi-pada-Era-Pandemi-Studi-Kasus-Kelas-XI-di-SMA-Negeri-1-Pecangaan-dan-SMA-Walisongo-Pecangaan-Kabupaten-Jepara-Provinsi-Jawa-Tengah
# -----------
# 120 https://digilib.uns.ac.id/dokumen/detail/100828/LEARNING-LOSS-DALAM-PEMBELAJARAN-MENULIS-TEKS-EKSPOSISI-STUDI-KASUS-EFEK-PEMBELAJARAN-JARAK-JAUH-DIKELAS-VIII-SMP-WARGA-SURAKARTA
# -----------
# 121 https://digilib.uns.ac.id/dokumen/detail/100871/Drilling-Technique-to-Students-Vocabulary-Enhancement-A-Case-Study-at-Fastco-English-Course
# -----------
# 122 https://digilib.uns.ac.id/dokumen/detail/100859/Penerapan-Model-Pembelajaran-Problem-Based-Learning-PBL-dengan-Media-Konkret-untuk-Meningkatkan-Pembelajaran-Matematika-tentang-Bangun-Ruang-pada-Siswa-Kelas-VA-SD-Negeri-1-Kutosari-Tahun-Ajaran-20222023
# -----------
# 123 https://digilib.uns.ac.id/dokumen/detail/100934/EXPLORING-STUDENTS-MOTIVATION-IN-ONLINE-EFL-CLASS-DURING-COVID-19-SOCIAL-RESTRICTION-NARRATIVE-INQUIRY
# -----------
# 124 https://digilib.uns.ac.id/dokumen/detail/100935/Penerapan-Model-Problem-Based-Learning-PBL-dengan-Multimedia-Untuk-Meningkatkan-Hasil-Belajar-IPS-tentang-Peristiwa-dalam-Kehidupan-Pada-Siswa-Kelas-VB-SDN-4-Kutosari-Tahun-Ajaran-20222023
# -----------
# 125 https://digilib.uns.ac.id/dokumen/detail/90443/Implementasi-Nilai-Kejujuran-Dalam-Membentuk-Karakter-Privat-Melalui-Pembelajaran-PPKn-Studi-Pada-Peserta-Didik-Kelas-X-SMA-Negeri-5-Surakarta
# -----------
# 126 https://digilib.uns.ac.id/dokumen/detail/90409/Tinjauan-Pengaruh-Game-Based-Learning-Terhadap-Perkembangan-Computational-Thinking-Skills-dari-Perspektif-Teori-Brennan-Resnick
# -----------
# 127 https://digilib.uns.ac.id/dokumen/detail/90990/Pengembangan-Mobile-Learning-dengan-Aplikasi-Padlet-untuk-Meningkatkan-Kemandirian-dan-Hasil-Belajar-Geografi-Peserta-Didik-Kelas-X-IPS-di-SMA-Negeri-6-Surakarta-Tahun-Ajaran-20212022
# -----------
# 128 https://digilib.uns.ac.id/dokumen/detail/91398/Pengembangan-Media-Pembelajaran-Matematika-Berbasis-M-Learning-pada-Materi-Transformasi-Geometri-Kelas-XI-IPS-SMA-Negeri-Jumapolo-Tahun-Ajaran-20212022
# -----------
# 129 https://digilib.uns.ac.id/dokumen/detail/91432/Kajian-Serapan-CO2-dan-Karbonasi-pada-Beton-Mutu-Tinggi-Memadat-Mandiri-dengan-Metakaolin-125n-Variasi-Agregat-Limbah-Pecahan-Keramik
# -----------
# 130 https://digilib.uns.ac.id/dokumen/detail/91628/MENGAMANKAN-DATA-MIGRASI-PADA-SISTEM-CLOUD-CENTERS-DENGAN-MODEL-K-MEANS-INITIALIZER-MIXTURE-LOCALIZATION-BASED-OUTLIERS
# -----------
# 131 https://digilib.uns.ac.id/dokumen/detail/91629/Hubungan-Kebiasaan-Tidur-dengan-Perkembangan-Anak-Prasekolah-di-TK-Aisyiyah-9-Sumberagung
# -----------
# 132 https://digilib.uns.ac.id/dokumen/detail/91616/Pengembangan-E-Modul-Berbasis-POGIL-Process-Oriented-Guided-Inquiry-Learning-Pada-Materi-Sistem-Respirasi-Manusia-Untuk-Memberdayakan-Keterampilan-Berpikir-Kritis-Siswa
# -----------
# 133 https://digilib.uns.ac.id/dokumen/detail/85687/Pengembangan-Buku-Digital-Sejarah-Perjuangan-Haji-Saman-Hudi-melalui-Discovery-Learning-untuk-Meningkatkan-Literasi-Sejarah-Siswa-di-SMA-Negeri-7-Surakarta
# -----------
# 134 https://digilib.uns.ac.id/dokumen/detail/86214/Disharmoni-Manusia-dengan-Lingkungan-dalam-Novel-Karya-Eka-Kurniawan-dan-Pemanfaatannya-sebagai-Pendidikan-Kesadaran-Ekologi-dalam-Pembelajaran-Bahasa-Indonesia-di-SMAKajian-Ekokritik-Sastra
# -----------
# 135 https://digilib.uns.ac.id/dokumen/detail/91146/Analisis-Gaya-Bahasa-dan-Nilai-Pendidikan-Karakter-dalam-Antologi-Geguritan-Kawula-Mung-Saderma-Karya-Jadid-Al-Farisy-serta-Relevansinya-sebagai-Materi-Ajar-Kelas-XII-SMA
# -----------
# 136 https://digilib.uns.ac.id/dokumen/detail/92689/PENGEMBANGAN-BAHAN-AJAR-PPKn-BERBASIS-MOBILE-LEARNING-UNTUK-MENINGKATKAN-KETERAMPILAN-SOSIAL-PADA-PESERTA-DIDIK-SMA-DI-SURAKARTA
# -----------
# 137 https://digilib.uns.ac.id/dokumen/detail/86875/Pengembangan-Media-Pembelajaran-Mobile-Learning-Berbasis-Androoid-pada-Materi-Perakitan-Komputer-di-Kelas-X-RPL-SMK-N-5-Surakarta
# -----------
# 138 https://digilib.uns.ac.id/dokumen/detail/87070/Pengembangan-e-Modul-IPA-Berbasis-Pogil-SSI-Process-Oriented-Guided-Inquiry-Learning-Socioscientific-Issues-untuk-Meningkatkan-Kemampuan-Berpikir-Kreatif-dan-Penguasaan-Konsep-Siswa
# -----------
# 139 https://digilib.uns.ac.id/dokumen/detail/86096/Pengembangan-Digital-Book-Sejarah-Lokal-Upacara-Adat-Belian-melalui-Pendekatan-Humanistik-untuk-Meningkatkan-Kesadaran-Sejarah-Peserta-Didik-SMA-di-Kota-Pangkalanan-Kerinci
# -----------
# 140 https://digilib.uns.ac.id/dokumen/detail/84983/Pengembangan-Modul-Produk-Kreatif-dan-Kewirausahaan-berbasis-Model-Project-Based-Learning-dan-Media-Spreadsheet-untuk-Meningkatkan-Kreativitas-Peserta-Didik-Bidang-Keahlian-Akuntansi-Sekolah-Menengah-Kejuruan-di-Kota-Surakarta
# -----------
# 141 https://digilib.uns.ac.id/dokumen/detail/84986/Pengembangan-Learning-Package-Model-Project-Based-Learning-Pembuatan-Film-Pendek-Materi-Pencemaran-Lingkungan-untuk-Meningkatkan-Kemampuan-Berpikir-Kreatif-Siswa
# -----------
# 142 https://digilib.uns.ac.id/dokumen/detail/85210/Inovasi-Model-Problem-Based-Learning-melalui-Google-Classroom-untuk-Menguatkan-Civic-Knowledge-Siswa-pada-Pembelajaran-Dalam-Jaringan-Studi-pada-Mata-Pelajaran-PPKn-di-SMK-Negeri-9-Surakarta
# -----------
# 143 https://digilib.uns.ac.id/dokumen/detail/85620/Penerapan-Penfdekatan-Dilemnas-Stories-pada-Materi-Hidrolisis-Garam-dengan-Model-Think-Pair-Share-TPSuntuk-Mengembangkan-Soft-Skill-Siswa-Kelas-XI-MIPA-4-di-SMA-NEGERI-1-Teras-Boyolali
# -----------
# 144 https://digilib.uns.ac.id/dokumen/detail/85388/Pengembangan-Media-Website-Bioenial-Biology-Electronic-Activity-Based-Learning-Berbasis-Keterampilan-Proses-Sains-Pada-Materi-Sistem-Pernapasan
# -----------
# 145 https://digilib.uns.ac.id/dokumen/detail/85467/Penentuan-Prioritas-Usulan-Perbaikan-Kualitas-Layanan-Pengguna-Aplikasi-Ruangguru-Dengan-Menggunakan-Metode-Importance-Performance-Analysis
# -----------
# 146 https://digilib.uns.ac.id/dokumen/detail/85579/Transformasi-Digital-Sistem-Pengambilan-Ktp-Elektronik-Di-Masa-New-Normal-Melalui-Autonomous-Line-Follower-Mobile-Robot-Berbasis-Mikrokontroler-Arduino-Uno-R3-Studi-Dinas-Kependudukan-dan-Pencatatan-Sipil-Kabupaten-Klaten
# -----------
# 147 https://digilib.uns.ac.id/dokumen/detail/85581/Pengembangan-Modul-Matematika-dengan-Pendekatan-Contextual-Teaching-and-Learning-untuk-Meningkatkan-Kemampuan-Koneksi-Matematis-pada-Materi-Fungsi
# -----------
# 148 https://digilib.uns.ac.id/dokumen/detail/85639/Pengaruh-Organizational-Learning-pada-Kinerja-Karyawan-Serta-Peran-Mediasi-Kepuasan-Kerja-dan-Komitmen-Organisasional-Karyawan-Universitas-Sebelas-Maret-Surakarta
# -----------
# 149 https://digilib.uns.ac.id/dokumen/detail/85642/Konfigurasi-Argumentasi-Berdasarkan-Concept-Map-Materi-Bryophyta-Menggunakan-Pembelajaran-Case-Based-Learning
# -----------
# 150 https://digilib.uns.ac.id/dokumen/detail/86551/Teachers-Perception-and-Practice-in-Teaching-Reading-Using-Online-Platform-A-Case-Study-in-a-Lower-Secondary-School-in-Ngawi
# -----------
# 151 https://digilib.uns.ac.id/dokumen/detail/85707/Pengembangan-Komik-Digital-untuk-Meningkatkan-Pemahaman-Sosiologi-Materi-Interaksi-Sosial-bagi-Anak-Slow-Learner-di-Kelas-Inklusi
# -----------
# 152 https://digilib.uns.ac.id/dokumen/detail/85756/Implementasi-Pembelajaran-Daring-berbasis-Model-Project-Based-Learning-pada-Materi-Redoks-terhadap-Hasil-Belajar-dan-Kemampuan-Berpikir-Kritis-Siswa-Kelas-X-MIPA-1-SMAN-1-Ngemplak-Boyolali
# -----------
# 153 https://digilib.uns.ac.id/dokumen/detail/85786/Exploring-Non-Millennial-Teachers-Strategies-to-Improve-Their-Online-Teaching-Performance-during-Coronavirus-Outbreak
# -----------
# 154 https://digilib.uns.ac.id/dokumen/detail/85793/Bridging-Formal-and-Informal-Digital-Learning-of-English-through-Spolskys-Language-Policy-A-Case-Study
# -----------
# 155 https://digilib.uns.ac.id/dokumen/detail/85912/Pengaruh-Discovery-Learning-menggunakan-Probing-Prompting-terhadap-Hasil-Belajar-Siswa-pada-Mata-Pelajaran-Dasar-dasar-Teknik-Jaringan-Komputer-dan-Telekomunikasi-Kelas-X-TKJ-SMKN-2-Surakarta
# -----------
# 156 https://digilib.uns.ac.id/dokumen/detail/85937/Analisis-Antropologi-Sastra-Nilai-Pendidikan-Karakter-Novel-Upacara-dan-Api-Awan-Asap-Karya-Korrie-Layun-Rampan-Serta-Pemanfaatannya-Sebagai-Materi-Ajar-Sastra-di-SMA
# -----------
# 157 https://digilib.uns.ac.id/dokumen/detail/86080/Upaya-Meningkatkan-Hasil-Belajar-Mata-Pelajaran-Administrasi-Umum-melalui-Metode-Mengajar-Discovery-Learning-Peserta-Didik-Kelas-X-OTKP-1
# -----------
# 158 https://digilib.uns.ac.id/dokumen/detail/86091/Model-Komunikasi-Persuasif-Keluarga-di-Era-New-Normal
# -----------
# 159 https://digilib.uns.ac.id/dokumen/detail/86192/Eksperimentasi-Pengajaran-Matematika-Menggunakan-Model-Pembelajaran-Learning-Cycle-5e-Ditinjau-dari-Minat-Belajar-Matematika-Siswa-pada-Materi-Program-Linier-di-SMK-N-1-Banyudono-Tahun-Ajaran-20192020
# -----------
# 160 https://digilib.uns.ac.id/dokumen/detail/86207/Hubungan-Self-Efficacy-dan-Dukungan-Sosial-Keluarga-dengan-Self-Regulated-Learning-Selama-Masa-Pandemi-Covid-19-pada-Siswa-SMA-Trisoko-Jakarta
# -----------
# 161 https://digilib.uns.ac.id/dokumen/detail/86225/Pengembangan-E-modul-Berbasis-Problem-Based-Learning-Pada-Materi-Sistem-Pencernaan-Untuk-Melatihkan-Kemampuan-Berpikir-Kritis-Siswa-SMP
# -----------
# 162 https://digilib.uns.ac.id/dokumen/detail/86256/Pre-service-Teachers-Experience-in-Creating-Quizzes-as-Informal-Digital-Learning-of-English-Activity-Focusing-on-Vocabulary-An-Autobiographical-Narrative-Inquiry
# -----------
# 163 https://digilib.uns.ac.id/dokumen/detail/86553/Pengembangan-Learning-Progression-Untuk-Mengetahui-Profil-Pemahaman-Konsep-Biodiversitas-Siswa-Sekolah-Menengah-Atas
# -----------
# 164 https://digilib.uns.ac.id/dokumen/detail/86292/Pengembangan-Alat-Ukur-Keterampilan-Kolaborasi-pada-Blended-Learning
# -----------
# 165 https://digilib.uns.ac.id/dokumen/detail/86439/Identifikasi-Potensi-Jemparingan-Gaya-Mataraman-Oleh-Komunitas-SIPAS-Sebagai-Daya-Tarik-Wisata-Minat-Khusus-di-Kota-Surakarta
# -----------
# 166 https://digilib.uns.ac.id/dokumen/detail/86409/Keefektifan-Pengembangan-Instrumen-Tes-Kemampuan-Berpikir-Tingkat-Tinggi-pada-Pembelajaran-Akuntansi-di-SMK-Kabupaten-Sukoharjo
# -----------
# 167 https://digilib.uns.ac.id/dokumen/detail/86441/Implementasi-Transfer-Learning-untuk-Deteksi-Penyakit-COVID-19-dan-Pneumonia-Melalui-Citra-Rontgen-Dada-Berbasis-Web
# -----------
# 168 https://digilib.uns.ac.id/dokumen/detail/86460/The-English-Pre-Service-Teachers-Perception-Toward-Translanguaging-in-EFL-Classroom
# -----------
# 169 https://digilib.uns.ac.id/dokumen/detail/86526/Pengembangan-E-modul-Bermuatan-Problem-Based-Learning-untuk-Meningkatkan-Kemampuan-Pemecahan-Masalah-Berdasarkan-Teori-John-Dewey-pada-Siswa-SMA
# -----------
# 170 https://digilib.uns.ac.id/dokumen/detail/86545/Pengembangan-Learning-Progression-Materi-Infectious-Disease
# -----------
# 171 https://digilib.uns.ac.id/dokumen/detail/86990/Analisis-Tingkat-Self-Regulated-Learning-pada-Mahasiswa-JPTK-Selama-Pandemi-Covid-19
# -----------
# 172 https://digilib.uns.ac.id/dokumen/detail/86620/Pengembangan-Spesix-Learning-Management-System-LMS-Guna-Meningkatkan-Hasil-Belajar-Siswa-SMPN-6-Semarang
# -----------
# 173 https://digilib.uns.ac.id/dokumen/detail/86616/Pengembangan-Perangkat-Pembelajaran-dengan-Model-PBL-Problem-Based-Learning-untuk-Meningkatkan-Kemampuan-Penyelesaian-Masalah-Pecahan-berdasarkan-Langkah-Polya-Penelitian-Pengembangan-pada-Siswa-Kelas-IV-SD-Negeri-di-Kecamatan-Girimarto-Kabupaten-Wonogiri
# -----------
# 174 https://digilib.uns.ac.id/dokumen/detail/86722/Examining-the-Extensive-Speaking-Practice-for-Instagram-Live-Shows-A-Narrative-Inquiry-Research-in-an-EFL-Context
# -----------
# 175 https://digilib.uns.ac.id/dokumen/detail/86788/Students-Perceptions-of-Video-Viewing-as-an-Out-of-Class-Learning-Activity
# -----------
# 176 https://digilib.uns.ac.id/dokumen/detail/86812/The-Implementation-of-Project-Based-Learning-in-Business-English-Conversation-Class
# -----------
# 177 https://digilib.uns.ac.id/dokumen/detail/86887/Pengembangan-Media-Virtual-Laboratory-Berbasis-Problem-Based-Learning-untuk-Meningkatkan-Kemampuan-Berpikir-Kritis-Siswa-SMP-pada-Materi-Sistem-Eskresi
# -----------
# 178 https://digilib.uns.ac.id/dokumen/detail/86867/Pengembangan-Mobile-Learning-Berbasis-Android-Untuk-Meningkatkan-Kepedulian-Lingkungan-Peserta-Didik-Kelas-X-IPS-di-SMA-Negeri-Kebakkramat-Kabupaten-Karanganyar-Tahun-2021
# -----------
# 179 https://digilib.uns.ac.id/dokumen/detail/86894/Analisis-Kebutuhan-Air-Domestik-di-Kabupaten-Sukoharjo-Tahun-2020
# -----------
# 180 https://digilib.uns.ac.id/dokumen/detail/86950/Studi-Penerapan-Culturally-Responsive-Transformative-Teaching-CRTT-pada-Materi-Hidrolisis-Garam-untuk-Mengembangkan-Soft-Skill-Siswa-Kelas-XI-MIPA-2-SMA-Al-Islam-1-Surakarta
# -----------
# 181 https://digilib.uns.ac.id/dokumen/detail/86960/Integrasi-Kecakapan-Abad-21-dalam-Kecakapan-Abad-21-Dalam-Pembelajaran-IPA-Materi-Kalor-dengan-Menggunakan-Blended-Learning-System-Pada-Peserta-Didik-Kelas-5B-SDIT-Mutiara-Karanggede-Boyolali-Tahun-Pelajaran-20202021
# -----------
# 182 https://digilib.uns.ac.id/dokumen/detail/86984/Investigating-The-Adoption-of-Active-Learning-Approach-in-Online-Class-Environment-A-Case-Study-in-One-of-The-Senior-High-Schools-in-Surakarta
# -----------
# 183 https://digilib.uns.ac.id/dokumen/detail/86988/Perbandingan-Penerapan-Model-Pembelajaran-Discovery-Learning-Dengan-Creative-Problem-Solving-dalam-Meningkatkan-Pemahaman-Konsep-dan-Hasil-Belajar-Peserta-Didik-pada-Mata-Pelajaran-Sistem-Komputer-di-SMK-Negeri-6-Surakarta
# -----------
# 184 https://digilib.uns.ac.id/dokumen/detail/87141/Analisis-Matematis-Siswa-Sekolah-Menengah-Pertama-dalam-Penyelesaian-Masalah-Berbasis-High-Order-Thinking-Skill-pada-Materi-Pokok-BangunRuang-Sisi-Datar
# -----------
# 185 https://digilib.uns.ac.id/dokumen/detail/87086/Pengembangan-Media-Pembelajaran-Mobile-Learning-Berbasis-Android-Menggunakan-Smart-Apps-Creator-untuk-Meningkatkan-Minat-dan-Prestasi-Belajar-Siswa-dalam-Materi-Ikatan-Kimia-SMA-Kelas-X
# -----------
# 186 https://digilib.uns.ac.id/dokumen/detail/87251/Pengembangan-Model-Pembelajaran-Historical-Group-Research-Berbasis-Pedagogi-Kritis-untuk-Meningkatkan-Keterampilan-Berpikir-Historis-Peserta-Didik-SMA-Negeri-1-Giri-Taruna-Bangsa-Banyuwangi
# -----------
# 187 https://digilib.uns.ac.id/dokumen/detail/87240/Analisis-Pemahaman-Konsep-Biodiversitas-Bryophyta-Berbasis-Learning-Progression-pada-Siswa-Kelas-10-dan-11
# -----------
# 188 https://digilib.uns.ac.id/dokumen/detail/87259/Design-Research-on-Mathematics-Education-Batik-as-Means-to-Support-High-School-Students-Learning-of-Geometric-Transformation
# -----------
# 189 https://digilib.uns.ac.id/dokumen/detail/87282/Pengaruh-antara-Pelatihan-dan-Kinerja-Pekerjaan-dengan-Mediasi-Kesesuaian-Pekerjaan-Pembelajaran-dan-Keterlibatan-Kerja-Studi-pada-Pegawai-Negeri-Sipil-PNS-di-Pemerintah-Kota-Madiun
# -----------
# 190 https://digilib.uns.ac.id/dokumen/detail/87320/Pengembangan-Media-Website-Interaktif-Berbasis-Keterampilan-Proses-Sains-pada-Materi-Animalia-untuk-Kelas-X-Sekolah-Menengah-Atas
# -----------
# 191 https://digilib.uns.ac.id/dokumen/detail/87327/Investigating-English-Education-Department-Students-Speaking-Anxiety-During-the-COVID-19-Outbreak-A-Case-Study
# -----------
# 192 https://digilib.uns.ac.id/dokumen/detail/87414/Strategi-Peningkatan-Kualitas-Pelayanan-PT-Kereta-Api-Indonesia-KAI-DAOP-II-Bandung-Pada-Masa-Pandemi-Covid-19
# -----------
# 193 https://digilib.uns.ac.id/dokumen/detail/87424/Analisis-Sentimen-pada-Komentar-Youtube-Mengenai-Vaksin-Covid-19-dengan-Menggunakan-Metode-Support-Vector-Machine
# -----------
# 194 https://digilib.uns.ac.id/dokumen/detail/87539/Perancangan-Interior-Children-Education-Center-dengan-Konsep-Montessori-Learning-di-Era-New-Normal
# -----------
# 195 https://digilib.uns.ac.id/dokumen/detail/87649/Eksperimentasi-Model-PJBL-dengan-Menggunakandiskusi-Forum-dan-Video-Conference-pada-Google-Classroom-Ditinjau-dari-Kemampuan-Representasi-Siswa-dalam-Pembelajaran-Fisika
# -----------
# 196 https://digilib.uns.ac.id/dokumen/detail/87569/Engaging-Students-in-A-Digital-Storytelling-Project-with-TPACK-21CL-Framework-in-Teaching-Content-Focused-Writing
# -----------
# 197 https://digilib.uns.ac.id/dokumen/detail/87643/Exploring-Students-Learning-Enjoyment-and-Vocabulary-Mastery-in-Digital-Game-Based-Learning-Experience
# -----------
# 198 https://digilib.uns.ac.id/dokumen/detail/87644/Pengaruh-Model-Pembelajaran-Problem-Solving-Dan-Problem-Based-Learning-Terhadap-Kemampuan-Berpikir-Kritis-Ditinjau-Dari-Motivasi-Belajar-Peserta-Didik-Pada-Pembelajaran-Akuntansi-di-SMKN-1-Surakarta
# -----------
# 199 https://digilib.uns.ac.id/dokumen/detail/87603/Eksperimentasi-Model-Pembelajaran-Problem-Based-Learning-dan-Problem-Posing-terhadap-Kemampuan-Berpikir-Kritis-dan-Kreatif-pada-Materi-Matriks-Ditinjau-dari-Adversity-Quotient-Siswa-Kelas-X-SMK-Swasta-Se-Kota-Surakarta

# %%
final_result = pd.DataFrame(all_result, columns=['Judul', 'Subyek', 'Abstrak', 'Pembimbing'])

# %%
final_result
# Out:
#                                                  Judul Subyek  \
# 0    Identifikasi Hipertensi menggunakan Heart Rate...      -
# 1    ANALISIS SENTIMEN TERKAIT TANGGAPAN TUDUHAN NE...      -
# 2    Rasio Keuangan pada Lima Bank di Indonesia den...      -
# 3    Model Prediksi Kekeringan Menggunakan Machine ...      -
# 4    Tinjauan Teknis Studi Supervised Machine Learn...
# ..                                                 ...    ...
# 195  Eksperimentasi Model PJBL dengan Menggunakandi...
# 196  Engaging Students in A Digital Storytelling Pr...      -
# 197  Exploring Student’s Learning Enjoyment and Voc...
# 198  Pengaruh Model Pembelajaran Problem Solving Da...      -
# 199  Eksperimentasi Model Pembelajaran Problem Base...
#
#                                                Abstrak  \
# 0    Hipertensi adalah keadaan di mana tekanan dara...
# 1    Covid 19 telah menginfeksi lebih dari 80 juta ...
# 2    Krisis yang terjadi di Indonesia telah mengaki...
# 3    Kekeringan adalah kondisi dimana kebutuhan air...
# 4    Penggunaan teknologi dalam kehidupan sehari-ha...
# ..                                                 ...
# 195  Awalinda Adji Nur Said. K2317009. EKSPERIMENTA...
# 196  ABSTRACTSaptiwi Rohayati. S891902020. 2022. En...
# 197  Given that Digital Game-Based Learning has gai...
# 198  Penelitian ini bertujuan untuk menguji 1) perb...
# 199  Kompetensi penting yang harus dimiliki setiap ...
#
#                                             Pembimbing
# 0    1. Prof. Nuryani, S.Si., M.Si., Ph.D.2. Dr. Um...
# 1                        1. Arofah Minasari, S.S. M.A.
# 2    1. Dr. Dewi Retno Sari S., S.Si., M.Kom.2. Nug...
# 3    1. Dr. Ir. RR. Rintis Hadiani, M.T.2. Ir. Adi ...
# 4    1. Dr.Eng. Aditya Rio Prabowo, S.T., M.T., M.E...
# ..                                                 ...
# 195  1. Dr. Sarwanto. S.Pd, M.Pd. 2. Dewanto Harjun...
# 196  1. Dr. Nur Arifah Drajati, M. Pd.2. Prof. Dr. ...
# 197  1. Dr. Nur Arifah Drajati, M.Pd2. Ellisa Indri...
# 198  1. Prof. Dr. Sunardi, M.Sc.2. Dr. Susilaningsi...
# 199      1. Dr. Mardiyana, M.Si. 2. Dr. Triyanto, M.Si
#
# [200 rows x 4 columns]

# %%
final_result.to_csv('data_digilib.csv', index=False)
